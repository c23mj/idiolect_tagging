# %%
import json
import os
import gzip
from collections import defaultdict
from tqdm import tqdm
import glob

input_dir = "/shared/4/datasets/long-reddit/"
output_dir = "/shared/3/projects/hiatus/idiolect/data/pilot/long-reddit"
output_path = os.path.join(output_dir, "corpus.jsonl")

# Make sure the output directory exists
os.makedirs(output_dir, exist_ok=True)

author_counts = defaultdict(list)

# Define the latest year to include in the dataset
latest_year = 2020

# for file in glob.glob(os.path.join(input_dir, "*.gz")):
#     print(file[-10:-6])
# Find all .gz files in the directory and filter by year
gz_files = [file for file in glob.glob(os.path.join(input_dir, "*.gz")) if int(file[-10:-6]) <= latest_year]

# print(gz_files)
# Process each file
for file_path in gz_files:
    with gzip.open(file_path, 'rt', encoding='utf-8') as file:
        for line in tqdm(file, desc=f"Processing {file_path}"):
            try:
                doc = json.loads(line)
                if "author" in doc: 
                    author_counts[doc["author"]].append(doc)
            except json.JSONDecodeError:
                pass  # Ignore the JSON decode error and move on
# Out:
# Processing /shared/4/datasets/long-reddit/RC_2007-12.gz: 3845it [00:00, 18546.91it/s]
# Processing /shared/4/datasets/long-reddit/RC_2007-07.gz: 2329it [00:00, 19164.74it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-06.gz: 5546it [00:00, 24567.75it/s]
# Processing /shared/4/datasets/long-reddit/RC_2009-07.gz: 18361it [00:00, 21533.22it/s]
# Processing /shared/4/datasets/long-reddit/RC_2016-06.gz: 619269it [00:43, 14175.30it/s]
# Processing /shared/4/datasets/long-reddit/RC_2013-06.gz: 276482it [00:18, 14665.74it/s]
# Processing /shared/4/datasets/long-reddit/RC_2017-06.gz: 684042it [00:47, 14351.02it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-04.gz: 331it [00:00, 15521.43it/s]
# Processing /shared/4/datasets/long-reddit/RC_2012-02.gz: 150459it [00:10, 15005.59it/s]
# Processing /shared/4/datasets/long-reddit/RC_2009-06.gz: 14566it [00:01, 13830.66it/s]
# Processing /shared/4/datasets/long-reddit/RC_2013-10.gz: 303669it [00:21, 13821.36it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-10.gz: 726it [00:00, 5878.81it/s]
# Processing /shared/4/datasets/long-reddit/RC_2014-11.gz: 392303it [00:26, 14767.53it/s]
# Processing /shared/4/datasets/long-reddit/RC_2014-12.gz: 419539it [00:26, 15697.38it/s]
# Processing /shared/4/datasets/long-reddit/RC_2009-01.gz: 11310it [00:00, 13101.26it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-01.gz: 4136it [00:00, 12169.02it/s]
# Processing /shared/4/datasets/long-reddit/RC_2018-12.gz: 877141it [01:53, 7732.29it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-10.gz: 7618it [00:00, 14042.95it/s]
# Processing /shared/4/datasets/long-reddit/RC_2013-09.gz: 278278it [00:19, 14320.96it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-12.gz: 9238it [00:00, 13715.45it/s]
# Processing /shared/4/datasets/long-reddit/RC_2019-08.gz: 1063552it [02:27, 7230.60it/s]
# Processing /shared/4/datasets/long-reddit/RC_2011-12.gz: 128178it [00:07, 17289.18it/s]
# Processing /shared/4/datasets/long-reddit/RC_2007-02.gz: 1344it [00:00, 17780.72it/s]
# Processing /shared/4/datasets/long-reddit/RC_2018-11.gz: 859916it [01:14, 11542.99it/s]
# Processing /shared/4/datasets/long-reddit/RC_2017-11.gz: 696055it [00:48, 14405.05it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-09.gz: 875it [00:00, 11218.28it/s]
# Processing /shared/4/datasets/long-reddit/RC_2015-06.gz: 484311it [00:31, 15184.09it/s]
# Processing /shared/4/datasets/long-reddit/RC_2019-06.gz: 1000494it [02:09, 7717.44it/s]
# Processing /shared/4/datasets/long-reddit/RC_2005-12.gz: 21it [00:00, 7839.82it/s]
# Processing /shared/4/datasets/long-reddit/RC_2011-08.gz: 105001it [00:07, 13403.63it/s]
# Processing /shared/4/datasets/long-reddit/RC_2016-04.gz: 564471it [00:41, 13556.60it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-02.gz: 4035it [00:00, 11410.27it/s]
# Processing /shared/4/datasets/long-reddit/RC_2016-03.gz: 604038it [00:45, 13196.65it/s]
# Processing /shared/4/datasets/long-reddit/RC_2015-05.gz: 486317it [00:36, 13269.38it/s]
# Processing /shared/4/datasets/long-reddit/RC_2010-05.gz: 33117it [00:02, 14141.62it/s]
# Processing /shared/4/datasets/long-reddit/RC_2014-08.gz: 402458it [00:28, 14056.51it/s]
# Processing /shared/4/datasets/long-reddit/RC_2013-08.gz: 304659it [00:28, 10732.52it/s]
# Processing /shared/4/datasets/long-reddit/RC_2010-06.gz: 34816it [00:02, 13224.84it/s]
# Processing /shared/4/datasets/long-reddit/RC_2019-10.gz: 1029335it [01:58, 8710.92it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-11.gz: 847it [00:00, 10953.18it/s]
# Processing /shared/4/datasets/long-reddit/RC_2011-01.gz: 67343it [00:04, 14233.91it/s]
# Processing /shared/4/datasets/long-reddit/RC_2007-08.gz: 2458it [00:00, 16465.22it/s]
# Processing /shared/4/datasets/long-reddit/RC_2015-01.gz: 468364it [00:34, 13555.61it/s]
# Processing /shared/4/datasets/long-reddit/RC_2011-06.gz: 87610it [00:05, 14835.26it/s]
# Processing /shared/4/datasets/long-reddit/RC_2007-04.gz: 1481it [00:00, 13192.49it/s]
# Processing /shared/4/datasets/long-reddit/RC_2017-07.gz: 711086it [00:52, 13455.75it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-03.gz: 129it [00:00, 11268.20it/s]
# Processing /shared/4/datasets/long-reddit/RC_2017-04.gz: 655409it [00:48, 13639.89it/s]
# Processing /shared/4/datasets/long-reddit/RC_2006-08.gz: 850it [00:00, 11999.90it/s]
# Processing /shared/4/datasets/long-reddit/RC_2018-07.gz: 882456it [01:36, 9116.70it/s]
# Processing /shared/4/datasets/long-reddit/RC_2010-11.gz: 56680it [00:03, 15015.85it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-07.gz: 6342it [00:00, 14720.68it/s]
# Processing /shared/4/datasets/long-reddit/RC_2010-08.gz: 43567it [00:03, 13911.98it/s]
# Processing /shared/4/datasets/long-reddit/RC_2012-03.gz: 165808it [00:10, 16060.22it/s]
# Processing /shared/4/datasets/long-reddit/RC_2016-12.gz: 625889it [00:40, 15494.04it/s]
# Processing /shared/4/datasets/long-reddit/RC_2013-01.gz: 261046it [00:34, 7610.55it/s]
# Processing /shared/4/datasets/long-reddit/RC_2008-11.gz: 7599it [00:00, 13336.02it/s]

# %%
# import json
# import os
# from collections import defaultdict 
# from tqdm import tqdm

# file_path= "/shared/3/projects/hiatus/aggregated_trainset_v2/raw_datasets/bookcorpus/corpus.jsonl"
# output_path = "/shared/3/projects/hiatus/idiolect/data/pilot/bookcorpus/corpus.jsonl"

# os.makedirs(os.path.dirname(output_path), exist_ok = True)

# author_counts = defaultdict(list)
# with open(file_path, 'r') as file:
#     for line in tqdm(file, desc = f"processing {file_path}"):
#         doc = json.loads(line)
#         if len(doc['authorIDs']) == 1 and doc['lengthWords'] >= 150:  
#             author_id = doc['authorIDs'][0]
#             author_counts[author_id].append(doc)
# # print(author_counts)

# %%
def print_stats(post_counts):
    total_posts = 0
    authors_over_5 = 0
    authors_over_10 = 0

    for author, posts in post_counts.items():
        total_posts += len(posts)
        
        if len(posts) >= 5:
            authors_over_5 += 1
        if len(posts) >= 10:
            authors_over_10 += 1

    total_authors = len(post_counts)
    avg_posts = float(total_posts) / total_authors if total_authors else 0.0

    print(f"Total number of authors: {total_authors}")
    print(f"Total number of posts: {total_posts}")
    print(f"Average number of posts per author: {avg_posts:.2f}")
    print(f"Total number of authors with at least 5 posts : {authors_over_5}")
    print(f"Total number of authors with at least 10 posts: {authors_over_10}")

print_stats(author_counts)
# Out:
# Total number of authors: 7208158
# Total number of posts: 70893122
# Average number of posts per author: 9.84
# Total number of authors with at least 5 posts : 1770314
# Total number of authors with at least 10 posts: 984685

# %%
import time 
bots = grab_bot_accounts()
non_bots = list(set(author_counts.keys()) - set(bots))
sorted_author_count = sorted(non_bots, key=lambda author: len(author_counts[author]), reverse=True)
total = 0
for author in sorted_author_count[100:1100]:
    time.sleep(0.01)
    total += len(author_counts[author])
#     print(author_counts[author][0])
#     print(len(author_counts[author]))
print(total)

# %%
# print(len(author_counts[sorted_author_count[100]]))
# docs = set()
# count = 0
# for post in author_counts[sorted_author_count[100]]:
#     if post['body'] not in docs:
#         count += 1
#         docs.add(post['body'])
# print(count)
print(total)
# Out:
# 2452319

# %%
import json

# Path to your output .jsonl file

# Open the file for writing
with open(output_path, 'w') as file:
    # Iterate over all sorted authors
    for author in tqdm(sorted_author_count[100:1100], desc = f"writing author documents to {output_path}"):
        # Iterate over each document in the list associated with the author
        for document in author_counts[author]:
            # Assuming each document is already a dictionary that can be serialized to JSON
            json_string = json.dumps(document)
            file.write(json_string + '\n')

# %%
def grab_bot_accounts():
    fname = '/shared/0/projects/prosocial/known-bots.tsv'
    bots = []

    with open(fname, 'rt') as f:
        lines = f.readlines()

        for line in lines:
            bots.append(line.split('\t')[1])

    print("Known bots: %d" % len(bots))
    bots.append('[deleted]')
    bots.append('deleted')
    bots.append('AutoModerator')
    return bots

# %%
# Out:
# Known bots: 393
